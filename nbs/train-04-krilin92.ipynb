# %% [markdown]
# # Imports

# %%
# %load_ext autoreload

# %%
# %autoreload 2

import functools
import operator
from functools import partial
import logging
import pathlib
from pathlib import Path
from pprint import pprint
import sys
from typing import *
import time
import yaml
from yaml import YAMLObject

import humanize
from matplotlib import pyplot as plt, cm
import numpy as np
import pandas as pd
from pymicro.file import file_utils
import tensorflow as tf
from numpy.random import RandomState

from tensorflow import keras
from tensorflow.keras import utils
from tensorflow.keras import optimizers
from tensorflow.keras import callbacks as keras_callbacks
from tensorflow.keras import losses
from tensorflow.keras import metrics as keras_metrics

from tomo2seg import slack
from tomo2seg import modular_unet
from tomo2seg.logger import logger
from tomo2seg import data, viz
from tomo2seg.data import Volume
from tomo2seg.metadata import Metadata
from tomo2seg.volume_sequence import (
    MetaCrop3DGenerator, VolumeCropSequence,
    UniformGridPosition, SequentialGridPosition,
    ET3DUniformCuboidAlmostEverywhere, ET3DConstantEverywhere, 
    GTUniformEverywhere, GTConstantEverywhere, 
    VSConstantEverywhere, VSUniformEverywhere
)
from tomo2seg import volume_sequence
from tomo2seg.model import Model as Tomo2SegModel
from tomo2seg import callbacks as tomo2seg_callbacks
from tomo2seg import losses as tomo2seg_losses
from tomo2seg import schedule as tomo2seg_schedule
from tomo2seg import utils as tomo2seg_utils

# %% [markdown]
# # Setup

# %%
logger.setLevel(logging.DEBUG)

# %%
random_state = 42
random_state = np.random.RandomState(random_state)
runid = int(time.time())
# runid = 1606238421
logger.info(f"{runid=}")
# Out:
# INFO::tomo2seg::{<ipython-input-4-f5dd942bd525>:<module>:005}::[2020-12-09::18:09:25.451]
# runid=1607533765

# %%
n_gpus = len(tf.config.list_physical_devices('GPU'))
    
logger.debug(f"{tf.__version__=}")
logger.info(f"Num GPUs Available: {n_gpus}\nThis should be 2 on R790-TOMO.")
logger.debug(f"Should return 2 devices...\n{tf.config.list_physical_devices('GPU')=}")
logger.debug(f"Should return 2 devices...\n{tf.config.list_logical_devices('GPU')=}")

# xla auto-clustering optimization (see: https://www.tensorflow.org/xla#auto-clustering)
# this seems to break the training
tf.config.optimizer.set_jit(False)

# get a distribution strategy to use both gpus (see https://www.tensorflow.org/guide/distributed_training)
strategy = tf.distribute.MirroredStrategy()
# Out:
# DEBUG::tomo2seg::{<ipython-input-5-3220786131f1>:<module>:003}::[2020-12-09::18:09:25.519]
# tf.__version__='2.2.0'
#
# INFO::tomo2seg::{<ipython-input-5-3220786131f1>:<module>:004}::[2020-12-09::18:09:25.520]
# Num GPUs Available: 1
# This should be 2 on R790-TOMO.
#
# DEBUG::tomo2seg::{<ipython-input-5-3220786131f1>:<module>:005}::[2020-12-09::18:09:25.521]
# Should return 2 devices...
# tf.config.list_physical_devices('GPU')=[PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
#
# DEBUG::tomo2seg::{<ipython-input-5-3220786131f1>:<module>:006}::[2020-12-09::18:09:25.619]
# Should return 2 devices...
# tf.config.list_logical_devices('GPU')=[LogicalDevice(name='/device:GPU:0', device_type='GPU')]
#
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)

# %% [markdown]
# # Args

# %%
MULTIPLE_REQUIREMENT = 16
logger.info(f"{MULTIPLE_REQUIREMENT=}")

# these are estimates based on things i've seen fit in the GPU
MAX_INTERNAL_NVOXELS = max(
    # seen cases
    4 * (8 * 6) * (96**3),
    8 * (16 * 6) * (320**2),  
    3 * (16 * 6) * (800 * 928),
)

MAX_INTERNAL_NVOXELS *= 5/8  # a smaller gpu on other pcs...

logger.info(f"{MAX_INTERNAL_NVOXELS=} ({humanize.intcomma(MAX_INTERNAL_NVOXELS)})")

# override_batch_size = None
# doing this to reproduce the same conditions...
override_batch_size_per_gpu = 8
# Out:
# INFO::tomo2seg::{<ipython-input-8-47a20a733e5b>:<module>:002}::[2020-12-09::18:09:51.733]
# MULTIPLE_REQUIREMENT=16
#
# INFO::tomo2seg::{<ipython-input-8-47a20a733e5b>:<module>:014}::[2020-12-09::18:09:51.735]
# MAX_INTERNAL_NVOXELS=133632000.0 (133,632,000.0)

# %% [markdown]
# # Data

# %%
from tomo2seg.datasets import (
    VOLUME_COMPOSITE_V1 as VOLUME_NAME_VERSION,
#     VOLUME_COMPOSITE_V1_REDUCED as VOLUME_NAME_VERSION,
    VOLUME_COMPOSITE_V1_LABELS_REFINED3 as LABELS_VERSION
)

volume_name, volume_version = VOLUME_NAME_VERSION
labels_version = LABELS_VERSION

logger.info(f"{volume_name=}")
logger.info(f"{volume_version=}")
logger.info(f"{labels_version=}")
# Out:
# INFO::tomo2seg::{<ipython-input-10-cd76321aa4c8>:<module>:010}::[2020-12-09::18:10:08.241]
# volume_name='PA66GF30'
#
# INFO::tomo2seg::{<ipython-input-10-cd76321aa4c8>:<module>:011}::[2020-12-09::18:10:08.243]
# volume_version='v1'
#
# INFO::tomo2seg::{<ipython-input-10-cd76321aa4c8>:<module>:012}::[2020-12-09::18:10:08.244]
# labels_version='refined3'

# %%
# Metadata/paths objects

## Volume
volume = Volume.with_check(
    name=volume_name, version=volume_version
)
logger.info(f"{volume=}")

n_classes = len(volume.metadata.labels)

def _read_raw(path_: Path, volume_: Volume): 
    # from pymicro
    return file_utils.HST_read(
        str(path_),  # it doesn't accept paths...
        # pre-loaded kwargs
        autoparse_filename=False,  # the file names are not properly formatted
        data_type=volume.metadata.dtype,
        dims=volume.metadata.dimensions,
        verbose=True,
    )

read_raw = partial(_read_raw, volume_=volume)

logger.info("Loading data from disk.")

## Data
voldata = read_raw(volume.data_path) / 255  # normalize
logger.debug(f"{voldata.shape=}")

voldata_train = volume.train_partition.get_volume_partition(voldata)
voldata_val = volume.val_partition.get_volume_partition(voldata)

logger.debug(f"{voldata_train.shape=}")
logger.debug(f"{voldata_val.shape=}")

del voldata

## Labels
vollabels = read_raw(volume.versioned_labels_path(labels_version))
logger.debug(f"{vollabels.shape=}")

vollabels_train = volume.train_partition.get_volume_partition(vollabels)
vollabels_val = volume.val_partition.get_volume_partition(vollabels)

logger.debug(f"{vollabels_train.shape=}")
logger.debug(f"{vollabels_val.shape=}")

del vollabels
# Out:
# DEBUG::tomo2seg::{data.py:with_check:258}::[2020-12-09::18:10:10.565]
# vol=Volume(name='PA66GF30', version='v1', _metadata=None)
#
# DEBUG::tomo2seg::{data.py:metadata:195}::[2020-12-09::18:10:10.573]
# Loading metadata from `/home/users/jcasagrande/projects/tomo2seg/data/PA66GF30.v1/PA66GF30.v1.metadata.yml`.
#
# INFO::tomo2seg::{<ipython-input-11-6e0649e4ec97>:<module>:007}::[2020-12-09::18:10:10.587]
# volume=Volume(name='PA66GF30', version='v1', _metadata=Volume.Metadata(dimensions=[1300, 1040, 1900], dtype='uint8', labels=[0, 1, 2], labels_names={0: 'matrix', 1: 'fiber', 2: 'porosity'}, set_partitions={'train': {'x_range': [0, 1300], 'y_range': [0, 1040], 'z_range': [0, 1300], 'alias': 'train'}, 'val': {'x_range': [0, 1300], 'y_range': [0, 1040], 'z_range': [1600, 1900], 'alias': 'val'}, 'test': {'x_range': [0, 1300], 'y_range': [0, 1040], 'z_range': [1300, 1600], 'alias': 'test'}}))
#
# INFO::tomo2seg::{<ipython-input-11-6e0649e4ec97>:<module>:024}::[2020-12-09::18:10:10.589]
# Loading data from disk.
#
# data type is uint8
# volume size is 1300 x 1040 x 1900
# reading volume... from byte 0
# DEBUG::tomo2seg::{<ipython-input-11-6e0649e4ec97>:<module>:028}::[2020-12-09::18:10:15.264]
# voldata.shape=(1300, 1040, 1900)
#
# DEBUG::tomo2seg::{<ipython-input-11-6e0649e4ec97>:<module>:033}::[2020-12-09::18:10:15.265]
# voldata_train.shape=(1300, 1040, 1300)
#
# DEBUG::tomo2seg::{<ipython-input-11-6e0649e4ec97>:<module>:034}::[2020-12-09::18:10:15.266]
# voldata_val.shape=(1300, 1040, 300)
#
# data type is uint8
# volume size is 1300 x 1040 x 1900
# reading volume... from byte 0
# DEBUG::tomo2seg::{<ipython-input-11-6e0649e4ec97>:<module>:040}::[2020-12-09::18:11:27.083]
# vollabels.shape=(1300, 1040, 1900)
#
# DEBUG::tomo2seg::{<ipython-input-11-6e0649e4ec97>:<module>:045}::[2020-12-09::18:11:27.084]
# vollabels_train.shape=(1300, 1040, 1300)
#
# DEBUG::tomo2seg::{<ipython-input-11-6e0649e4ec97>:<module>:046}::[2020-12-09::18:11:27.085]
# vollabels_val.shape=(1300, 1040, 300)

# %% [markdown]
# # Model

# %%
try:
    tomo2seg_model
except NameError:
    print("already deleted (:")
else:
    del tomo2seg_model
# Out:
# already deleted (:

# %%
# crop_shape = (256, 256, 1)  # multiple of 16 (requirement of a 4-level u-net)
# bigger crops will have less border effects (?)
crop_shape = (112, 112, 1)  # multiple of 16 (requirement of a 4-level u-net)

model_master_name = "unet2d"
model_version = "crop112-f16"
model_factory_function = modular_unet.u_net

model_is_2halfd = False
model_is_2d = True

model_factory_kwargs = {
    **modular_unet.kwargs_vanilla03,
    **dict(
        convlayer=modular_unet.ConvLayer.conv2d,
        input_shape = crop_shape,
        output_channels=n_classes,
#         nb_filters_0 = 2,
#         nb_filters_0 = 4,
#         nb_filters_0 = 8,
#         nb_filters_0 = 12,
        nb_filters_0 = 16,
#         nb_filters_0 = 32,
    ),
}

# %%
try:
    tomo2seg_model
    
except NameError:
    logger.info("Creating a Tomo2SegModel.")
    
    tomo2seg_model = Tomo2SegModel(
        model_master_name, 
        model_version, 
        runid=runid,
        factory_function=model_factory_function,
        factory_kwargs=model_factory_kwargs,
    )
                
else:
    logger.warning("The model is already defined. To create a new one: `del tomo2seg_model`")

finally:
    
    logger.info(f"{tomo2seg_model=}")
    
logger.info("Creating the Keras model.")

with strategy.scope():
    if not tomo2seg_model.autosaved_model_path.exists():
        logger.info(f"Instantiating a new model with model_factory_function={model_factory_function.__name__}")
      
        model = model_factory_function(
            name=tomo2seg_model.name,
            **model_factory_kwargs
        )
    else:
        logger.warning("An autosaved model already exists, loading it instead of creating a new one!")
        model = keras.models.load_model(tomo2seg_model.autosaved_model_path_str, compile=False)

    logger.info("Compiling the model.")

    # using the avg jaccard is dangerous if one of the classes is too
    # underrepresented because it's jaccard will be unstable
    loss = tomo2seg_losses.jaccard2_flat

    optimizer = optimizers.Adam(lr=.003)
    metrics = [
#         tomo2seg_losses.jaccard2_macro_avg,
#         keras_metrics.Accuracy(),
#     ] + [
#         tomo2seg_losses.Jaccard2(class_idx)
#         for class_idx in range(n_classes)
    ]

    model.compile(
        loss=loss, 
        optimizer=optimizer,
        metrics=metrics,
    )
    model.save(tomo2seg_model.model_path)

    # write the model summary in a file
    with tomo2seg_model.summary_path.open("w") as f:
        def print_to_txt(line):
            f.writelines([line + "\n"])
        model.summary(print_fn=print_to_txt, line_length=140)

    # same for the architecture
    utils.plot_model(model, show_shapes=True, to_file=tomo2seg_model.architecture_plot_path);

    logger.info(f"Check the summary and the figure of the model in the following locations:\n{tomo2seg_model.summary_path}\n{tomo2seg_model.architecture_plot_path}")
# Out:
# WARNING::tomo2seg::{<ipython-input-15-2291d74903ed>:<module>:016}::[2020-12-09::18:12:01.347]
# The model is already defined. To create a new one: `del tomo2seg_model`
#
# INFO::tomo2seg::{<ipython-input-15-2291d74903ed>:<module>:020}::[2020-12-09::18:12:01.348]
# tomo2seg_model=Model(master_name='unet2d', version='crop112-f16', fold=0, runid=1607533765, factory_function='tomo2seg.modular_unet.u_net', factory_kwargs={'depth': 4, 'sigma_noise': 0, 'updown_conv_sampling': True, 'unet_block_kwargs': {'kernel_size': 3, 'res': True, 'batch_norm': True, 'dropout': 0}, 'unet_down_kwargs': {'batchnorm': True}, 'unet_up_kwargs': {'batchnorm': True}, 'convlayer': <ConvLayer.conv2d: 0>, 'input_shape': (112, 112, 1), 'output_channels': 3, 'nb_filters_0': 16})
#
# INFO::tomo2seg::{<ipython-input-15-2291d74903ed>:<module>:022}::[2020-12-09::18:12:01.349]
# Creating the Keras model.
#
# INFO::tomo2seg::{<ipython-input-15-2291d74903ed>:<module>:026}::[2020-12-09::18:12:01.350]
# Instantiating a new model with model_factory_function=u_net
#
# INFO::tomo2seg::{<ipython-input-15-2291d74903ed>:<module>:036}::[2020-12-09::18:12:03.035]
# Compiling the model.
#
# INFO:tensorflow:Assets written to: /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/assets
# INFO::tomo2seg::{<ipython-input-15-2291d74903ed>:<module>:067}::[2020-12-09::18:12:15.620]
# Check the summary and the figure of the model in the following locations:
# /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/summary.txt
# /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/architecture.png

# %% [markdown]
# # Data crop sequences

# %% [markdown]
# ## Batch size

# %%
model_internal_nvoxel_factor = tomo2seg_utils.get_model_internal_nvoxel_factor(model)

logger.debug(f"{model_internal_nvoxel_factor=}")

max_batch_nvoxels = int(np.floor(MAX_INTERNAL_NVOXELS / model_internal_nvoxel_factor))

logger.debug(f"{max_batch_nvoxels=} ({humanize.intcomma(max_batch_nvoxels)})")

crop_nvoxels = functools.reduce(operator.mul, crop_shape)

logger.debug(f"{crop_shape=} ==> {crop_nvoxels=}")

max_batch_size_per_gpu = batch_size_per_gpu = int(np.floor(max_batch_nvoxels / crop_nvoxels))

logger.info(f"{batch_size_per_gpu=}")

if override_batch_size_per_gpu is not None:
    
    assert override_batch_size_per_gpu > 0, f"{override_batch_size_per_gpu=}"
    
    batch_size_per_gpu = override_batch_size_per_gpu
    
    logger.warning(f"{override_batch_size_per_gpu=} given ==> replacing {batch_size_per_gpu=}")

logger.info(f"{n_gpus=}")

batch_size = batch_size_per_gpu * max(1, n_gpus)

logger.info(f"{batch_size=}")

common_random_state = 143
# Out:
# DEBUG::tomo2seg::{utils.py:get_model_internal_nvoxel_factor:017}::[2020-12-09::18:12:34.213]
# input_layer=<tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7f9488441c40>
#
# DEBUG::tomo2seg::{utils.py:get_model_internal_nvoxel_factor:023}::[2020-12-09::18:12:34.215]
# input_nvoxels=12544
#
# DEBUG::tomo2seg::{utils.py:get_model_internal_nvoxel_factor:037}::[2020-12-09::18:12:34.218]
# max_internal_nvoxels=1204224 (1,204,224)
#
# DEBUG::tomo2seg::{<ipython-input-17-46fe188ba465>:<module>:003}::[2020-12-09::18:12:34.219]
# model_internal_nvoxel_factor=96
#
# DEBUG::tomo2seg::{<ipython-input-17-46fe188ba465>:<module>:007}::[2020-12-09::18:12:34.220]
# max_batch_nvoxels=1392000 (1,392,000)
#
# DEBUG::tomo2seg::{<ipython-input-17-46fe188ba465>:<module>:011}::[2020-12-09::18:12:34.221]
# crop_shape=(112, 112, 1) ==> crop_nvoxels=12544
#
# INFO::tomo2seg::{<ipython-input-17-46fe188ba465>:<module>:015}::[2020-12-09::18:12:34.222]
# batch_size_per_gpu=110
#
# WARNING::tomo2seg::{<ipython-input-17-46fe188ba465>:<module>:023}::[2020-12-09::18:12:34.224]
# override_batch_size_per_gpu=8 given ==> replacing batch_size_per_gpu=8
#
# INFO::tomo2seg::{<ipython-input-17-46fe188ba465>:<module>:025}::[2020-12-09::18:12:34.224]
# n_gpus=1
#
# INFO::tomo2seg::{<ipython-input-17-46fe188ba465>:<module>:029}::[2020-12-09::18:12:34.225]
# batch_size=8

# %% [markdown]
# ## Train

# %%
from tomo2seg import volume_sequence

metacrop_gen_common_kwargs = dict(
    crop_shape=crop_shape,
    common_random_state_seed=common_random_state,
    is_2halfd=model_is_2halfd,
    gt_type=volume_sequence.GT2D if model_is_2d else volume_sequence.GT3D,
)

logger.debug(f"{metacrop_gen_common_kwargs=}")

vol_crop_seq_common_kwargs = dict(
    output_as_2d=model_is_2d,
    output_as_2halfd=model_is_2halfd,
    labels = volume.metadata.labels,

    # not automated...
    debug__no_data_check=True,
)

logger.debug(f"{vol_crop_seq_common_kwargs=}")
# Out:
# DEBUG::tomo2seg::{<ipython-input-20-8d35eacdfc70>:<module>:010}::[2020-12-09::18:13:20.818]
# metacrop_gen_common_kwargs={'crop_shape': (112, 112, 1), 'common_random_state_seed': 143, 'is_2halfd': False, 'gt_type': <enum 'GT2D'>}
#
# DEBUG::tomo2seg::{<ipython-input-20-8d35eacdfc70>:<module>:021}::[2020-12-09::18:13:20.819]
# vol_crop_seq_common_kwargs={'output_as_2d': True, 'output_as_2halfd': False, 'labels': [0, 1, 2], 'debug__no_data_check': True}

# %%
data = voldata_train
labels = vollabels_train

volume_shape = data.shape

crop_seq_train = VolumeCropSequence(
    data_volume=data,
    labels_volume=labels,
    
    batch_size=batch_size,
    
    meta_crop_generator=MetaCrop3DGenerator.build_setup_train00(
        volume_shape=volume_shape,
        **metacrop_gen_common_kwargs
    ),
    
    # this volume cropper only returns random crops, 
    # so the number of crops per epoch/batch is w/e i want
    epoch_size=10,
    
    **vol_crop_seq_common_kwargs,
)
# Out:
# INFO::tomo2seg::{volume_sequence.py:build_from_volume_crop_shapes:438}::[2020-12-09::18:13:31.129]
# Built UniformGridPosition from volume_shape=(1300, 1040, 1300) and crop_shape=(112, 112, 1) ==> {'x_range': (0, 1189), 'y_range': (0, 929), 'z_range': (0, 1300)}
#
# DEBUG::tomo2seg::{volume_sequence.py:__post_init__:400}::[2020-12-09::18:13:31.130]
# UniformGridPosition ==> npositions=1435955300 (1,435,955,300)
#
# WARNING::tomo2seg::{volume_sequence.py:__post_init__:695}::[2020-12-09::18:13:31.130]
# Initializing ET3DConstantEverywhere with a UniformGridPosition.
# The {x, y, z}_range values will be overwritten.
#
# WARNING::tomo2seg::{volume_sequence.py:__post_init__:695}::[2020-12-09::18:13:31.131]
# Initializing GTUniformEverywhere with a UniformGridPosition.
# The {x, y, z}_range values will be overwritten.
#
# WARNING::tomo2seg::{volume_sequence.py:__post_init__:695}::[2020-12-09::18:13:31.132]
# Initializing VSUniformEverywhere with a UniformGridPosition.
# The {x, y, z}_range values will be overwritten.
#
# DEBUG::tomo2seg::{volume_sequence.py:__post_init__:1353}::[2020-12-09::18:13:31.132]
# Initializing VolumeCropSequence.
#
# WARNING::tomo2seg::{volume_sequence.py:__post_init__:1385}::[2020-12-09::18:13:31.133]
# No meta crops history file path given. The randomly generated crops will not be saved!

# %% [markdown]
# ## Val

# %%
data = voldata_val
labels = vollabels_val

volume_shape = data.shape

# the validation has no reproducibility issues
# so let's push the GPUs (:
val_batch_size = max_batch_size_per_gpu * n_gpus

logger.debug(f"{val_batch_size=}")

grid_pos_gen = SequentialGridPosition.build_min_overlap(
    volume_shape=volume_shape, 
    crop_shape=crop_shape,
    # reduce the total number of crops
        n_steps_x=11,
        n_steps_y=11,
        n_steps_z=11,
)

crop_seq_val = VolumeCropSequence(
    data_volume=data,
    labels_volume=labels,
    
    batch_size=val_batch_size,
    
    # go through all the crops in validation
    epoch_size=len(grid_pos_gen),      
    
    # data augmentation
    meta_crop_generator=MetaCrop3DGenerator.build_setup_val00(
        volume_shape=volume_shape,
        grid_pos_gen=grid_pos_gen,
        **metacrop_gen_common_kwargs,
    ),
    
    **vol_crop_seq_common_kwargs,
)
# Out:
# DEBUG::tomo2seg::{<ipython-input-31-b438c21e5a8d>:<module>:010}::[2020-12-09::18:20:02.538]
# val_batch_size=110
#
# INFO::tomo2seg::{volume_sequence.py:build_min_overlap:506}::[2020-12-09::18:20:02.539]
# Building SequentialGridPosition with minimal overlap (smallest n_steps in each directions) n_steps={'n_steps_x': 12, 'n_steps_y': 10, 'n_steps_z': 300}.
#
# WARNING::tomo2seg::{volume_sequence.py:build_min_overlap:509}::[2020-12-09::18:20:02.540]
# n_steps_kwargs={'n_steps_x': 11, 'n_steps_y': 11, 'n_steps_z': 11} was given --> effective n_steps={'n_steps_x': 11, 'n_steps_y': 11, 'n_steps_z': 11}
#
# INFO::tomo2seg::{volume_sequence.py:build_from_volume_crop_shapes:438}::[2020-12-09::18:20:02.540]
# Built SequentialGridPosition from volume_shape=(1300, 1040, 300) and crop_shape=(112, 112, 1) ==> {'x_range': (0, 1189), 'y_range': (0, 929), 'z_range': (0, 300)}
#
# INFO::tomo2seg::{volume_sequence.py:__post_init__:486}::[2020-12-09::18:20:02.543]
# The SequentialGridPosition has len(self.positions)=1331 different positions (therefore crops).
#
# WARNING::tomo2seg::{volume_sequence.py:__post_init__:695}::[2020-12-09::18:20:02.543]
# Initializing ET3DConstantEverywhere with a SequentialGridPosition.
# The {x, y, z}_range values will be overwritten.
#
# WARNING::tomo2seg::{volume_sequence.py:__post_init__:695}::[2020-12-09::18:20:02.544]
# Initializing GTConstantEverywhere with a SequentialGridPosition.
# The {x, y, z}_range values will be overwritten.
#
# WARNING::tomo2seg::{volume_sequence.py:__post_init__:695}::[2020-12-09::18:20:02.545]
# Initializing VSConstantEverywhere with a SequentialGridPosition.
# The {x, y, z}_range values will be overwritten.
#
# DEBUG::tomo2seg::{volume_sequence.py:__post_init__:1353}::[2020-12-09::18:20:02.545]
# Initializing VolumeCropSequence.
#
# WARNING::tomo2seg::{volume_sequence.py:__post_init__:1385}::[2020-12-09::18:20:02.546]
# No meta crops history file path given. The randomly generated crops will not be saved!

# %% [markdown]
# # Callbacks

# %%
autosave_cb = keras_callbacks.ModelCheckpoint(
    tomo2seg_model.autosaved_model_path_str, 
    monitor="val_loss", 
    verbose=2, 
    save_best_only=True, 
    mode="auto",
)

# todo load if it already exists
try:
    history_cb
    
except NameError:
    history_cb = tomo2seg_callbacks.History(
        optimizer=model.optimizer,
        crop_seq_train=crop_seq_train,
        crop_seq_val=crop_seq_val,
        backup=1,
        csv_path=tomo2seg_model.history_path,
    )
    
else:
    logger.warning("The history callback already exists!")
    
    history_df = history_cb.dataframe

    try:
        history_df_temp = pd.read_csv(tomo2seg_model.history_path)
        # keep the longest one
        history_df = history_df if history_df.shape[0] >= history_df_temp.shape[0] else history_df_temp
        del history_df_temp
    
    except FileNotFoundError:
        logger.info("History hasn't been saved yet.")
        
    except pd.errors.EmptyDataError:
        logger.info("History hasn't been saved yet.")
        
finally:
    # make sure the correct objects are linked 
    history_cb.model = model
    history_cb.crop_seq_train = crop_seq_train
    history_cb.crop_seq_val = crop_seq_val
    # todo do the same with other objs in history_cb
    
history_plot_cb = tomo2seg_callbacks.HistoryPlot(
    history_callback=history_cb,
    save_path=tomo2seg_model.train_history_plot_wip_path
)

early_stop_cb = keras_callbacks.EarlyStopping(  # todo modify the early stopping to take more conditions (don't stop too early before it doesnt break the jaccard2=.32)
    monitor='val_loss', 
    min_delta=.1 / 100, 
    patience=50,
    verbose=2, 
    mode='auto',
    baseline=.71,  # 0th-order classifier
    restore_best_weights=False,
)
# Out:
# WARNING::tomo2seg::{<ipython-input-32-51b55b964faa>:<module>:023}::[2020-12-09::18:20:09.309]
# The history callback already exists!
#
# INFO::tomo2seg::{<ipython-input-32-51b55b964faa>:<module>:037}::[2020-12-09::18:20:09.311]
# History hasn't been saved yet.

# %% [markdown]
# # Summary before training
#
# stuff that i use after the training but i want it to appear in the

# %% [markdown]
# ## Metadata
#
# todo put this back to work
#
# ## Volume slices
#
# todo do this in a notebook
#
# ## Generator samples
#
# todo do this in a notebook

# %% [markdown]
# # Training

# %% [markdown]
# ## Teeth log lr schedule

# %%
lr_schedule_cb = keras_callbacks.LearningRateScheduler(
    schedule=(schedule := tomo2seg_schedule.get_schedule00()),
    verbose=2,
)

logger.info(f"{schedule.range}")

callbacks = [
    keras_callbacks.TerminateOnNaN(),
    autosave_cb,
    history_cb,
    history_plot_cb,
    lr_schedule_cb,
#     early_stop_cb,
]

for cb in callbacks:
    logger.debug(f"using callback {cb.__class__.__name__}")
# Out:
# INFO::tomo2seg::{schedule.py:__post_init__:071}::[2020-12-09::18:20:11.264]
# LogSpaceSchedule ==> self.n=10
#
# INFO::tomo2seg::{schedule.py:__post_init__:071}::[2020-12-09::18:20:11.266]
# LogSpaceSchedule ==> self.n=30
#
# INFO::tomo2seg::{schedule.py:__post_init__:071}::[2020-12-09::18:20:11.266]
# LogSpaceSchedule ==> self.n=20
#
# INFO::tomo2seg::{schedule.py:__post_init__:071}::[2020-12-09::18:20:11.267]
# LogSpaceSchedule ==> self.n=40
#
# INFO::tomo2seg::{schedule.py:__post_init__:071}::[2020-12-09::18:20:11.267]
# LogSpaceSchedule ==> self.n=20
#
# INFO::tomo2seg::{schedule.py:__post_init__:071}::[2020-12-09::18:20:11.268]
# LogSpaceSchedule ==> self.n=40
#
# INFO::tomo2seg::{schedule.py:__post_init__:071}::[2020-12-09::18:20:11.269]
# LogSpaceSchedule ==> self.n=100
#
# INFO::tomo2seg::{schedule.py:__post_init__:107}::[2020-12-09::18:20:11.269]
# ComposedSchedule ==> self.n=260
#
# INFO::tomo2seg::{<ipython-input-33-23215096d57e>:<module>:006}::[2020-12-09::18:20:11.270]
# (0, 260)
#
# DEBUG::tomo2seg::{<ipython-input-33-23215096d57e>:<module>:018}::[2020-12-09::18:20:11.270]
# using callback TerminateOnNaN
#
# DEBUG::tomo2seg::{<ipython-input-33-23215096d57e>:<module>:018}::[2020-12-09::18:20:11.271]
# using callback ModelCheckpoint
#
# DEBUG::tomo2seg::{<ipython-input-33-23215096d57e>:<module>:018}::[2020-12-09::18:20:11.272]
# using callback History
#
# DEBUG::tomo2seg::{<ipython-input-33-23215096d57e>:<module>:018}::[2020-12-09::18:20:11.272]
# using callback HistoryPlot
#
# DEBUG::tomo2seg::{<ipython-input-33-23215096d57e>:<module>:018}::[2020-12-09::18:20:11.273]
# using callback LearningRateScheduler

# %%
n_epochs = 400

try:
    model.fit(
        # data sequences
        x=crop_seq_train,
        validation_data=crop_seq_val,

        # epochs
        initial_epoch=0,
        epochs=n_epochs,
#         initial_epoch=history_cb.last_epoch + 1,  # for some reason it is 0-starting and others 1-starting...
#         epochs=history_cb.last_epoch + 1 + n_epochs,  
    #     initial_epoch=113,
    #     epochs=126,

        # others
        callbacks=callbacks,  
        verbose=2,
        use_multiprocessing=False,   
    );

except Exception as ex:
    slack.notify_error()
    raise ex
    
else:
    slack.notify_finished()
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 1/400
#
# Epoch 00001: val_loss improved from inf to 0.64489, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-09::18:31:41.879]
# Saving backup of the training history epoch=0 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{callbacks.py:on_epoch_end:117}::[2020-12-09::18:31:42.084]
# epoch=0 is too early to plot something.
#
# ERROR::tomo2seg::{callbacks.py:on_epoch_end:158}::[2020-12-09::18:31:42.238]
# AssertionError occurred while trying to plot the history.
# Traceback (most recent call last):
#   File "/home/users/jcasagrande/projects/tomo2seg/tomo2seg/callbacks.py", line 129, in on_epoch_end
#   File "<string>", line 9, in __init__
#   File "/home/users/jcasagrande/projects/tomo2seg/tomo2seg/viz.py", line 254, in __post_init__
#     assert len(x_axis) > 1, "You don't have enough epochs to plot. Go to the gym and call me later."
# AssertionError: You don't have enough epochs to plot. Go to the gym and call me later.
# 10/10 - 687s - loss: 0.4277 - val_loss: 0.6449 - lr: 1.0000e-04
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0001291549665014884.
# Epoch 2/400
#
# Epoch 00002: val_loss improved from 0.64489 to 0.61008, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-09::18:42:27.265]
# Saving backup of the training history epoch=1 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{callbacks.py:on_epoch_end:117}::[2020-12-09::18:42:27.297]
# epoch=1 is too early to plot something.
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-09::18:42:27.338]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::18:42:27.362]
# train: argmin=1 --> min=0.2
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::18:42:27.364]
# val: argmin=1 --> min=0.61
#
# 10/10 - 645s - loss: 0.2004 - val_loss: 0.6101 - lr: 1.2915e-04
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0001668100537200059.
# Epoch 3/400
#
# Epoch 00003: val_loss improved from 0.61008 to 0.56434, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-09::18:53:12.950]
# Saving backup of the training history epoch=2 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-09::18:53:13.015]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::18:53:13.038]
# train: argmin=2 --> min=0.101
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::18:53:13.040]
# val: argmin=2 --> min=0.564
#
# 10/10 - 645s - loss: 0.1015 - val_loss: 0.5643 - lr: 1.6681e-04
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.00021544346900318845.
# Epoch 4/400
#
# Epoch 00004: val_loss improved from 0.56434 to 0.50382, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-09::19:03:57.924]
# Saving backup of the training history epoch=3 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-09::19:03:57.984]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::19:03:58.007]
# train: argmin=3 --> min=0.0631
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::19:03:58.009]
# val: argmin=3 --> min=0.504
#
# 10/10 - 645s - loss: 0.0631 - val_loss: 0.5038 - lr: 2.1544e-04
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0002782559402207126.
# Epoch 5/400
#
# Epoch 00005: val_loss improved from 0.50382 to 0.42431, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-09::19:14:43.465]
# Saving backup of the training history epoch=4 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-09::19:14:43.528]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::19:14:43.551]
# train: argmin=4 --> min=0.0463
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::19:14:43.553]
# val: argmin=4 --> min=0.424
#
# 10/10 - 645s - loss: 0.0463 - val_loss: 0.4243 - lr: 2.7826e-04
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.00035938136638046257.
# Epoch 6/400
#
# Epoch 00006: val_loss improved from 0.42431 to 0.35116, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-09::19:25:28.967]
# Saving backup of the training history epoch=5 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-09::19:25:29.024]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::19:25:29.047]
# train: argmin=5 --> min=0.035
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::19:25:29.049]
# val: argmin=5 --> min=0.351
#
# 10/10 - 645s - loss: 0.0350 - val_loss: 0.3512 - lr: 3.5938e-04
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.00046415888336127773.
# Epoch 7/400
#
# Epoch 00007: val_loss improved from 0.35116 to 0.30064, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-09::19:36:14.555]
# Saving backup of the training history epoch=6 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-09::19:36:14.615]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::19:36:14.639]
# train: argmin=6 --> min=0.0334
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::19:36:14.640]
# val: argmin=6 --> min=0.301
#
# 10/10 - 645s - loss: 0.0334 - val_loss: 0.3006 - lr: 4.6416e-04
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005994842503189409.
# Epoch 8/400
#
# Epoch 00008: val_loss improved from 0.30064 to 0.27215, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-09::19:46:59.917]
# Saving backup of the training history epoch=7 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-09::19:46:59.983]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::19:47:00.009]
# train: argmin=7 --> min=0.0289
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::19:47:00.012]
# val: argmin=7 --> min=0.272
#
# 10/10 - 645s - loss: 0.0289 - val_loss: 0.2722 - lr: 5.9948e-04
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.000774263682681127.
# Epoch 9/400
#
# Epoch 00009: val_loss improved from 0.27215 to 0.25393, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-09::19:57:46.268]
# Saving backup of the training history epoch=8 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-09::19:57:46.331]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::19:57:46.354]
# train: argmin=8 --> min=0.0264
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::19:57:46.356]
# val: argmin=8 --> min=0.254
#
# 10/10 - 646s - loss: 0.0264 - val_loss: 0.2539 - lr: 7.7426e-04
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 10/400
#
# Epoch 00010: val_loss improved from 0.25393 to 0.24003, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-09::20:08:32.344]
# Saving backup of the training history epoch=9 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-09::20:08:32.426]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::20:08:32.449]
# train: argmin=9 --> min=0.0259
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::20:08:32.452]
# val: argmin=9 --> min=0.24
#
# 10/10 - 646s - loss: 0.0259 - val_loss: 0.2400 - lr: 0.0010
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 11/400
#
# Epoch 00011: val_loss improved from 0.24003 to 0.22972, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-09::20:19:18.044]
# Saving backup of the training history epoch=10 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-09::20:19:18.111]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::20:19:18.134]
# train: argmin=10 --> min=0.0248
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::20:19:18.136]
# val: argmin=10 --> min=0.23
#
# 10/10 - 645s - loss: 0.0248 - val_loss: 0.2297 - lr: 0.0010
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 12/400
#
# Epoch 00012: val_loss improved from 0.22972 to 0.22119, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-09::20:30:03.924]
# Saving backup of the training history epoch=11 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-09::20:30:03.995]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::20:30:04.021]
# train: argmin=10 --> min=0.0248
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::20:30:04.023]
# val: argmin=11 --> min=0.221
#
# 10/10 - 646s - loss: 0.0250 - val_loss: 0.2212 - lr: 0.0010
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 13/400
#
# Epoch 00013: val_loss improved from 0.22119 to 0.21470, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-09::20:40:50.194]
# Saving backup of the training history epoch=12 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-09::20:40:50.257]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::20:40:50.281]
# train: argmin=12 --> min=0.0245
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::20:40:50.282]
# val: argmin=12 --> min=0.215
#
# 10/10 - 646s - loss: 0.0245 - val_loss: 0.2147 - lr: 0.0010
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 14/400
#
# Epoch 00014: val_loss did not improve from 0.21470
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-09::20:51:31.918]
# Saving backup of the training history epoch=13 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-09::20:51:31.973]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::20:51:31.994]
# train: argmin=13 --> min=0.0229
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::20:51:31.996]
# val: argmin=12 --> min=0.215
#
# 10/10 - 642s - loss: 0.0229 - val_loss: 0.2208 - lr: 0.0010
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 15/400
#
# Epoch 00015: val_loss improved from 0.21470 to 0.21326, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-09::21:02:18.179]
# Saving backup of the training history epoch=14 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-09::21:02:18.246]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::21:02:18.269]
# train: argmin=14 --> min=0.0194
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::21:02:18.271]
# val: argmin=14 --> min=0.213
#
# 10/10 - 646s - loss: 0.0194 - val_loss: 0.2133 - lr: 0.0010
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 16/400
#
# Epoch 00016: val_loss did not improve from 0.21326
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-09::21:12:59.942]
# Saving backup of the training history epoch=15 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-09::21:13:00.008]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::21:13:00.031]
# train: argmin=15 --> min=0.0191
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::21:13:00.033]
# val: argmin=14 --> min=0.213
#
# 10/10 - 641s - loss: 0.0191 - val_loss: 0.2191 - lr: 0.0010
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 17/400
#
# Epoch 00017: val_loss improved from 0.21326 to 0.21224, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-09::21:23:46.638]
# Saving backup of the training history epoch=16 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-09::21:23:46.705]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::21:23:46.727]
# train: argmin=16 --> min=0.0188
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::21:23:46.729]
# val: argmin=16 --> min=0.212
#
# 10/10 - 647s - loss: 0.0188 - val_loss: 0.2122 - lr: 0.0010
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 18/400
#
# Epoch 00018: val_loss improved from 0.21224 to 0.20903, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-09::21:34:32.916]
# Saving backup of the training history epoch=17 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-09::21:34:32.984]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::21:34:33.007]
# train: argmin=16 --> min=0.0188
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::21:34:33.009]
# val: argmin=17 --> min=0.209
#
# 10/10 - 646s - loss: 0.0194 - val_loss: 0.2090 - lr: 0.0010
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 19/400
#
# Epoch 00019: val_loss did not improve from 0.20903
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-09::21:45:15.131]
# Saving backup of the training history epoch=18 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-09::21:45:15.201]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::21:45:15.223]
# train: argmin=16 --> min=0.0188
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::21:45:15.225]
# val: argmin=17 --> min=0.209
#
# 10/10 - 642s - loss: 0.0215 - val_loss: 0.2100 - lr: 0.0010
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 20/400
#
# Epoch 00020: val_loss improved from 0.20903 to 0.18737, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-09::21:56:02.017]
# Saving backup of the training history epoch=19 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-09::21:56:02.082]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::21:56:02.106]
# train: argmin=16 --> min=0.0188
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::21:56:02.108]
# val: argmin=19 --> min=0.187
#
# 10/10 - 647s - loss: 0.0195 - val_loss: 0.1874 - lr: 0.0010
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 21/400
#
# Epoch 00021: val_loss did not improve from 0.18737
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-09::22:06:44.418]
# Saving backup of the training history epoch=20 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-09::22:06:44.482]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::22:06:44.504]
# train: argmin=20 --> min=0.0185
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::22:06:44.506]
# val: argmin=19 --> min=0.187
#
# 10/10 - 642s - loss: 0.0185 - val_loss: 0.1927 - lr: 0.0010
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 22/400
#
# Epoch 00022: val_loss did not improve from 0.18737
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-09::22:17:26.991]
# Saving backup of the training history epoch=21 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-09::22:17:27.060]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::22:17:27.081]
# train: argmin=20 --> min=0.0185
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::22:17:27.083]
# val: argmin=19 --> min=0.187
#
# 10/10 - 642s - loss: 0.0193 - val_loss: 0.1906 - lr: 0.0010
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 23/400
#
# Epoch 00023: val_loss improved from 0.18737 to 0.17195, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-09::22:28:13.774]
# Saving backup of the training history epoch=22 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-09::22:28:13.842]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::22:28:13.865]
# train: argmin=20 --> min=0.0185
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::22:28:13.867]
# val: argmin=22 --> min=0.172
#
# 10/10 - 647s - loss: 0.0206 - val_loss: 0.1720 - lr: 0.0010
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 24/400
#
# Epoch 00024: val_loss improved from 0.17195 to 0.17014, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-09::22:39:00.496]
# Saving backup of the training history epoch=23 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-09::22:39:00.561]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::22:39:00.585]
# train: argmin=20 --> min=0.0185
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::22:39:00.587]
# val: argmin=23 --> min=0.17
#
# 10/10 - 646s - loss: 0.0207 - val_loss: 0.1701 - lr: 0.0010
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 25/400
#
# Epoch 00025: val_loss improved from 0.17014 to 0.15579, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-09::22:49:47.601]
# Saving backup of the training history epoch=24 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-09::22:49:47.664]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::22:49:47.687]
# train: argmin=24 --> min=0.0182
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::22:49:47.689]
# val: argmin=24 --> min=0.156
#
# 10/10 - 647s - loss: 0.0182 - val_loss: 0.1558 - lr: 0.0010
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 26/400
#
# Epoch 00026: val_loss improved from 0.15579 to 0.13957, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-09::23:00:35.040]
# Saving backup of the training history epoch=25 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-09::23:00:35.109]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::23:00:35.133]
# train: argmin=25 --> min=0.0178
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::23:00:35.135]
# val: argmin=25 --> min=0.14
#
# 10/10 - 647s - loss: 0.0178 - val_loss: 0.1396 - lr: 0.0010
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 27/400
#
# Epoch 00027: val_loss did not improve from 0.13957
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-09::23:11:17.985]
# Saving backup of the training history epoch=26 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-09::23:11:18.055]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::23:11:18.076]
# train: argmin=26 --> min=0.0173
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::23:11:18.078]
# val: argmin=25 --> min=0.14
#
# 10/10 - 643s - loss: 0.0173 - val_loss: 0.1409 - lr: 0.0010
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 28/400
#
# Epoch 00028: val_loss improved from 0.13957 to 0.12877, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-09::23:22:05.060]
# Saving backup of the training history epoch=27 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-09::23:22:05.123]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::23:22:05.146]
# train: argmin=26 --> min=0.0173
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::23:22:05.148]
# val: argmin=27 --> min=0.129
#
# 10/10 - 647s - loss: 0.0179 - val_loss: 0.1288 - lr: 0.0010
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 29/400
#
# Epoch 00029: val_loss improved from 0.12877 to 0.12300, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-09::23:32:52.281]
# Saving backup of the training history epoch=28 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-09::23:32:52.350]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::23:32:52.373]
# train: argmin=26 --> min=0.0173
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::23:32:52.375]
# val: argmin=28 --> min=0.123
#
# 10/10 - 647s - loss: 0.0187 - val_loss: 0.1230 - lr: 0.0010
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 30/400
#
# Epoch 00030: val_loss improved from 0.12300 to 0.10570, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-09::23:43:39.750]
# Saving backup of the training history epoch=29 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-09::23:43:39.819]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::23:43:39.841]
# train: argmin=29 --> min=0.0171
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::23:43:39.843]
# val: argmin=29 --> min=0.106
#
# 10/10 - 647s - loss: 0.0171 - val_loss: 0.1057 - lr: 0.0010
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 31/400
#
# Epoch 00031: val_loss did not improve from 0.10570
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-09::23:54:23.133]
# Saving backup of the training history epoch=30 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-09::23:54:23.193]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::23:54:23.215]
# train: argmin=29 --> min=0.0171
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-09::23:54:23.217]
# val: argmin=29 --> min=0.106
#
# 10/10 - 643s - loss: 0.0173 - val_loss: 0.1069 - lr: 0.0010
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.000774263682681127.
# Epoch 32/400
#
# Epoch 00032: val_loss improved from 0.10570 to 0.09908, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-10::00:05:10.892]
# Saving backup of the training history epoch=31 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-10::00:05:10.956]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::00:05:10.980]
# train: argmin=29 --> min=0.0171
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::00:05:10.982]
# val: argmin=31 --> min=0.0991
#
# 10/10 - 648s - loss: 0.0190 - val_loss: 0.0991 - lr: 7.7426e-04
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0005994842503189409.
# Epoch 33/400
#
# Epoch 00033: val_loss improved from 0.09908 to 0.09223, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-10::00:15:58.695]
# Saving backup of the training history epoch=32 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-10::00:15:58.756]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::00:15:58.779]
# train: argmin=32 --> min=0.0169
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::00:15:58.781]
# val: argmin=32 --> min=0.0922
#
# 10/10 - 648s - loss: 0.0169 - val_loss: 0.0922 - lr: 5.9948e-04
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.00046415888336127773.
# Epoch 34/400
#
# Epoch 00034: val_loss improved from 0.09223 to 0.08600, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-10::00:26:46.533]
# Saving backup of the training history epoch=33 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-10::00:26:46.599]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::00:26:46.622]
# train: argmin=32 --> min=0.0169
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::00:26:46.624]
# val: argmin=33 --> min=0.086
#
# 10/10 - 648s - loss: 0.0185 - val_loss: 0.0860 - lr: 4.6416e-04
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.00035938136638046257.
# Epoch 35/400
#
# Epoch 00035: val_loss improved from 0.08600 to 0.08266, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-10::00:37:34.268]
# Saving backup of the training history epoch=34 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-10::00:37:34.336]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::00:37:34.358]
# train: argmin=32 --> min=0.0169
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::00:37:34.360]
# val: argmin=34 --> min=0.0827
#
# 10/10 - 648s - loss: 0.0169 - val_loss: 0.0827 - lr: 3.5938e-04
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0002782559402207126.
# Epoch 36/400
#
# Epoch 00036: val_loss improved from 0.08266 to 0.07866, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-10::00:48:21.908]
# Saving backup of the training history epoch=35 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-10::00:48:21.964]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::00:48:21.986]
# train: argmin=32 --> min=0.0169
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::00:48:21.988]
# val: argmin=35 --> min=0.0787
#
# 10/10 - 647s - loss: 0.0176 - val_loss: 0.0787 - lr: 2.7826e-04
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.00021544346900318845.
# Epoch 37/400
#
# Epoch 00037: val_loss improved from 0.07866 to 0.07353, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-10::00:59:09.831]
# Saving backup of the training history epoch=36 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-10::00:59:09.896]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::00:59:09.919]
# train: argmin=32 --> min=0.0169
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::00:59:09.921]
# val: argmin=36 --> min=0.0735
#
# 10/10 - 648s - loss: 0.0173 - val_loss: 0.0735 - lr: 2.1544e-04
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0001668100537200059.
# Epoch 38/400
#
# Epoch 00038: val_loss improved from 0.07353 to 0.06763, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-10::01:09:57.689]
# Saving backup of the training history epoch=37 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-10::01:09:57.869]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::01:09:57.891]
# train: argmin=32 --> min=0.0169
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::01:09:57.893]
# val: argmin=37 --> min=0.0676
#
# 10/10 - 648s - loss: 0.0181 - val_loss: 0.0676 - lr: 1.6681e-04
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0001291549665014884.
# Epoch 39/400
#
# Epoch 00039: val_loss improved from 0.06763 to 0.06467, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-10::01:20:45.798]
# Saving backup of the training history epoch=38 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-10::01:20:45.872]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::01:20:45.895]
# train: argmin=32 --> min=0.0169
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::01:20:45.897]
# val: argmin=38 --> min=0.0647
#
# 10/10 - 648s - loss: 0.0179 - val_loss: 0.0647 - lr: 1.2915e-04
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 40/400
#
# Epoch 00040: val_loss improved from 0.06467 to 0.06230, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-10::01:31:33.669]
# Saving backup of the training history epoch=39 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-10::01:31:33.726]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::01:31:33.749]
# train: argmin=32 --> min=0.0169
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::01:31:33.751]
# val: argmin=39 --> min=0.0623
#
# 10/10 - 648s - loss: 0.0181 - val_loss: 0.0623 - lr: 1.0000e-04
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0001.
# Epoch 41/400
#
# Epoch 00041: val_loss improved from 0.06230 to 0.05883, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-10::01:42:21.542]
# Saving backup of the training history epoch=40 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-10::01:42:21.604]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::01:42:21.628]
# train: argmin=32 --> min=0.0169
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::01:42:21.630]
# val: argmin=40 --> min=0.0588
#
# 10/10 - 648s - loss: 0.0174 - val_loss: 0.0588 - lr: 1.0000e-04
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.00011288378916846895.
# Epoch 42/400
#
# Epoch 00042: val_loss improved from 0.05883 to 0.05532, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-10::01:53:09.640]
# Saving backup of the training history epoch=41 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-10::01:53:09.703]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::01:53:09.727]
# train: argmin=41 --> min=0.0158
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::01:53:09.729]
# val: argmin=41 --> min=0.0553
#
# 10/10 - 648s - loss: 0.0158 - val_loss: 0.0553 - lr: 1.1288e-04
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.00012742749857031334.
# Epoch 43/400
#
# Epoch 00043: val_loss improved from 0.05532 to 0.05009, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-10::02:03:57.699]
# Saving backup of the training history epoch=42 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-10::02:03:57.886]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::02:03:57.908]
# train: argmin=41 --> min=0.0158
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::02:03:57.910]
# val: argmin=42 --> min=0.0501
#
# 10/10 - 648s - loss: 0.0172 - val_loss: 0.0501 - lr: 1.2743e-04
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0001438449888287663.
# Epoch 44/400
#
# Epoch 00044: val_loss improved from 0.05009 to 0.04691, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-10::02:14:45.938]
# Saving backup of the training history epoch=43 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-10::02:14:46.014]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::02:14:46.036]
# train: argmin=41 --> min=0.0158
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::02:14:46.038]
# val: argmin=43 --> min=0.0469
#
# 10/10 - 648s - loss: 0.0175 - val_loss: 0.0469 - lr: 1.4384e-04
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0001623776739188721.
# Epoch 45/400
#
# Epoch 00045: val_loss improved from 0.04691 to 0.04644, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-10::02:25:34.001]
# Saving backup of the training history epoch=44 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-10::02:25:34.065]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::02:25:34.088]
# train: argmin=41 --> min=0.0158
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::02:25:34.090]
# val: argmin=44 --> min=0.0464
#
# 10/10 - 648s - loss: 0.0163 - val_loss: 0.0464 - lr: 1.6238e-04
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.00018329807108324357.
# Epoch 46/400
#
# Epoch 00046: val_loss improved from 0.04644 to 0.04307, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-10::02:36:22.242]
# Saving backup of the training history epoch=45 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-10::02:36:22.310]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::02:36:22.333]
# train: argmin=45 --> min=0.0154
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::02:36:22.335]
# val: argmin=45 --> min=0.0431
#
# 10/10 - 648s - loss: 0.0154 - val_loss: 0.0431 - lr: 1.8330e-04
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.00020691380811147902.
# Epoch 47/400
#
# Epoch 00047: val_loss improved from 0.04307 to 0.03932, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-10::02:47:10.335]
# Saving backup of the training history epoch=46 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-10::02:47:10.385]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::02:47:10.407]
# train: argmin=45 --> min=0.0154
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::02:47:10.409]
# val: argmin=46 --> min=0.0393
#
# 10/10 - 648s - loss: 0.0172 - val_loss: 0.0393 - lr: 2.0691e-04
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.00023357214690901214.
# Epoch 48/400
#
# Epoch 00048: val_loss did not improve from 0.03932
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-10::02:57:54.606]
# Saving backup of the training history epoch=47 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-10::02:57:54.675]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::02:57:54.697]
# train: argmin=45 --> min=0.0154
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::02:57:54.698]
# val: argmin=46 --> min=0.0393
#
# 10/10 - 644s - loss: 0.0169 - val_loss: 0.0398 - lr: 2.3357e-04
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.00026366508987303583.
# Epoch 49/400
#
# Epoch 00049: val_loss improved from 0.03932 to 0.03761, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-10::03:08:42.981]
# Saving backup of the training history epoch=48 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-10::03:08:43.058]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::03:08:43.081]
# train: argmin=45 --> min=0.0154
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::03:08:43.083]
# val: argmin=48 --> min=0.0376
#
# 10/10 - 648s - loss: 0.0176 - val_loss: 0.0376 - lr: 2.6367e-04
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.00029763514416313193.
# Epoch 50/400
#
# Epoch 00050: val_loss improved from 0.03761 to 0.03674, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-10::03:19:31.193]
# Saving backup of the training history epoch=49 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-10::03:19:31.253]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::03:19:31.276]
# train: argmin=45 --> min=0.0154
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::03:19:31.277]
# val: argmin=49 --> min=0.0367
#
# 10/10 - 648s - loss: 0.0174 - val_loss: 0.0367 - lr: 2.9764e-04
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0003359818286283781.
# Epoch 51/400
#
# Epoch 00051: val_loss improved from 0.03674 to 0.03349, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-10::03:30:19.956]
# Saving backup of the training history epoch=50 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-10::03:30:20.015]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::03:30:20.038]
# train: argmin=45 --> min=0.0154
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::03:30:20.039]
# val: argmin=50 --> min=0.0335
#
# 10/10 - 648s - loss: 0.0185 - val_loss: 0.0335 - lr: 3.3598e-04
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.000379269019073225.
# Epoch 52/400
#
# Epoch 00052: val_loss improved from 0.03349 to 0.03266, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-10::03:41:08.228]
# Saving backup of the training history epoch=51 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-10::03:41:08.287]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::03:41:08.310]
# train: argmin=45 --> min=0.0154
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::03:41:08.312]
# val: argmin=51 --> min=0.0327
#
# 10/10 - 648s - loss: 0.0165 - val_loss: 0.0327 - lr: 3.7927e-04
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.00042813323987193956.
# Epoch 53/400
#
# Epoch 00053: val_loss improved from 0.03266 to 0.03025, saving model to /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765.autosaved.hdf5
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-10::03:51:56.455]
# Saving backup of the training history epoch=52 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-10::03:51:56.518]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::03:51:56.541]
# ...
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-10::13:55:01.706]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::13:55:01.728]
# train: argmin=103 --> min=0.0139
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::13:55:01.730]
# val: argmin=101 --> min=0.0171
#
# 10/10 - 645s - loss: 0.0148 - val_loss: 0.0179 - lr: 2.6367e-04
#
# Epoch 00110: LearningRateScheduler reducing learning rate to 0.00029763514416313193.
# Epoch 110/400
#
# Epoch 00110: val_loss did not improve from 0.01712
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-10::14:05:46.654]
# Saving backup of the training history epoch=109 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-10::14:05:46.753]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::14:05:46.775]
# train: argmin=103 --> min=0.0139
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::14:05:46.777]
# val: argmin=101 --> min=0.0171
#
# 10/10 - 645s - loss: 0.0159 - val_loss: 0.0172 - lr: 2.9764e-04
#
# Epoch 00111: LearningRateScheduler reducing learning rate to 0.0003359818286283781.
# Epoch 111/400
#
# Epoch 00111: val_loss did not improve from 0.01712
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-10::14:16:29.594]
# Saving backup of the training history epoch=110 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-10::14:16:29.652]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::14:16:29.686]
# train: argmin=103 --> min=0.0139
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::14:16:29.688]
# val: argmin=101 --> min=0.0171
#
# 10/10 - 643s - loss: 0.0163 - val_loss: 0.0177 - lr: 3.3598e-04
#
# Epoch 00112: LearningRateScheduler reducing learning rate to 0.000379269019073225.
# Epoch 112/400
#
# Epoch 00112: val_loss did not improve from 0.01712
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-10::14:27:12.266]
# Saving backup of the training history epoch=111 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-10::14:27:12.336]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::14:27:12.358]
# train: argmin=103 --> min=0.0139
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::14:27:12.359]
# val: argmin=101 --> min=0.0171
#
# 10/10 - 642s - loss: 0.0159 - val_loss: 0.0173 - lr: 3.7927e-04
#
# Epoch 00113: LearningRateScheduler reducing learning rate to 0.00042813323987193956.
# Epoch 113/400
#
# Epoch 00113: val_loss did not improve from 0.01712
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-10::14:37:57.020]
# Saving backup of the training history epoch=112 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-10::14:37:57.088]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::14:37:57.108]
# train: argmin=103 --> min=0.0139
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::14:37:57.110]
# val: argmin=101 --> min=0.0171
#
# 10/10 - 645s - loss: 0.0164 - val_loss: 0.0173 - lr: 4.2813e-04
#
# Epoch 00114: LearningRateScheduler reducing learning rate to 0.0004832930238571752.
# Epoch 114/400
#
# Epoch 00114: val_loss did not improve from 0.01712
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-10::14:48:41.976]
# Saving backup of the training history epoch=113 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-10::14:48:42.043]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::14:48:42.066]
# train: argmin=103 --> min=0.0139
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::14:48:42.067]
# val: argmin=101 --> min=0.0171
#
# 10/10 - 645s - loss: 0.0165 - val_loss: 0.0175 - lr: 4.8329e-04
#
# Epoch 00115: LearningRateScheduler reducing learning rate to 0.000545559478116852.
# Epoch 115/400
#
# Epoch 00115: val_loss did not improve from 0.01712
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-10::14:59:26.831]
# Saving backup of the training history epoch=114 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-10::14:59:26.902]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::14:59:26.924]
# train: argmin=103 --> min=0.0139
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::14:59:26.926]
# val: argmin=101 --> min=0.0171
#
# 10/10 - 645s - loss: 0.0168 - val_loss: 0.0172 - lr: 5.4556e-04
#
# Epoch 00116: LearningRateScheduler reducing learning rate to 0.0006158482110660267.
# Epoch 116/400
#
# Epoch 00116: val_loss did not improve from 0.01712
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-10::15:10:11.615]
# Saving backup of the training history epoch=115 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-10::15:10:11.682]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::15:10:11.704]
# train: argmin=103 --> min=0.0139
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::15:10:11.706]
# val: argmin=101 --> min=0.0171
#
# 10/10 - 645s - loss: 0.0150 - val_loss: 0.0172 - lr: 6.1585e-04
#
# Epoch 00117: LearningRateScheduler reducing learning rate to 0.0006951927961775605.
# Epoch 117/400
#
# Epoch 00117: val_loss did not improve from 0.01712
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-10::15:20:56.708]
# Saving backup of the training history epoch=116 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-10::15:20:56.773]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::15:20:56.795]
# train: argmin=103 --> min=0.0139
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::15:20:56.797]
# val: argmin=101 --> min=0.0171
#
# 10/10 - 645s - loss: 0.0154 - val_loss: 0.0174 - lr: 6.9519e-04
#
# Epoch 00118: LearningRateScheduler reducing learning rate to 0.0007847599703514606.
# Epoch 118/400
#
# Epoch 00118: val_loss did not improve from 0.01712
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-10::15:31:41.461]
# Saving backup of the training history epoch=117 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-10::15:31:41.528]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::15:31:41.550]
# train: argmin=103 --> min=0.0139
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::15:31:41.552]
# val: argmin=101 --> min=0.0171
#
# 10/10 - 645s - loss: 0.0165 - val_loss: 0.0176 - lr: 7.8476e-04
#
# Epoch 00119: LearningRateScheduler reducing learning rate to 0.0008858667904100823.
# Epoch 119/400
#
# Epoch 00119: val_loss did not improve from 0.01712
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-10::15:42:26.598]
# Saving backup of the training history epoch=118 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-10::15:42:26.666]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::15:42:26.688]
# train: argmin=103 --> min=0.0139
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::15:42:26.690]
# val: argmin=101 --> min=0.0171
#
# 10/10 - 645s - loss: 0.0172 - val_loss: 0.0209 - lr: 8.8587e-04
#
# Epoch 00120: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 120/400
#
# Epoch 00120: val_loss did not improve from 0.01712
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-10::15:53:10.083]
# Saving backup of the training history epoch=119 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-10::15:53:10.142]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::15:53:10.162]
# train: argmin=103 --> min=0.0139
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::15:53:10.164]
# val: argmin=101 --> min=0.0171
#
# 10/10 - 643s - loss: 0.0157 - val_loss: 0.0177 - lr: 0.0010
#
# Epoch 00121: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 121/400
#
# Epoch 00121: val_loss did not improve from 0.01712
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-10::16:03:51.871]
# Saving backup of the training history epoch=120 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-10::16:03:51.940]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::16:03:51.962]
# train: argmin=103 --> min=0.0139
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::16:03:51.964]
# val: argmin=101 --> min=0.0171
#
# 10/10 - 642s - loss: 0.0160 - val_loss: 0.0189 - lr: 0.0010
#
# Epoch 00122: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 122/400
#
# Epoch 00122: val_loss did not improve from 0.01712
# INFO::tomo2seg::{callbacks.py:on_epoch_end:099}::[2020-12-10::16:14:42.497]
# Saving backup of the training history epoch=121 self.csv_path=PosixPath('/home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/history.csv')
#
# DEBUG::tomo2seg::{viz.py:plot:297}::[2020-12-10::16:14:42.565]
# TrainingHistoryDisplay.plot plotting loss
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::16:14:42.586]
# train: argmin=103 --> min=0.0139
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::16:14:42.588]
# val: argmin=101 --> min=0.0171
#
# 10/10 - 650s - loss: 0.0159 - val_loss: 0.0185 - lr: 0.0010
#
# Epoch 00123: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 123/400
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-5be902b67630> in <module>
#       2
#       3 try:
# ----> 4     model.fit(
#       5         # data sequences
#       6         x=crop_seq_train,
#
# ~/projects/tomo2seg/condaenv/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# ~/projects/tomo2seg/condaenv/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     860           val_x, val_y, val_sample_weight = (
#     861               data_adapter.unpack_x_y_sample_weight(validation_data))
# --> 862           val_logs = self.evaluate(
#     863               x=val_x,
#     864               y=val_y,
#
# ~/projects/tomo2seg/condaenv/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# ~/projects/tomo2seg/condaenv/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict)
#    1079                 step_num=step):
#    1080               callbacks.on_test_batch_begin(step)
# -> 1081               tmp_logs = test_function(iterator)
#    1082               # Catch OutOfRangeError for Datasets of unknown size.
#    1083               # This blocks until the batch has finished executing.
#
# ~/projects/tomo2seg/condaenv/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# ~/projects/tomo2seg/condaenv/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     616       # In this case we have not created variables on the first call. So we can
#     617       # run the first trace but we should fail if variables are created.
# --> 618       results = self._stateful_fn(*args, **kwds)
#     619       if self._created_variables:
#     620         raise ValueError("Creating variables on a non-first call to a function"
#
# ~/projects/tomo2seg/condaenv/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# ~/projects/tomo2seg/condaenv/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1659       `args` and `kwargs`.
#    1660     """
# -> 1661     return self._call_flat(
#    1662         (t for t in nest.flatten((args, kwargs), expand_composites=True)
#    1663          if isinstance(t, (ops.Tensor,
#
# ~/projects/tomo2seg/condaenv/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1743         and executing_eagerly):
#    1744       # No tape is watching; skip to running the function.
# -> 1745       return self._build_call_outputs(self._inference_function.call(
#    1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#
# ~/projects/tomo2seg/condaenv/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     591       with _InterpolateFunctionError(self):
#     592         if cancellation_manager is None:
# --> 593           outputs = execute.execute(
#     594               str(self.signature.name),
#     595               num_outputs=self._num_outputs,
#
# ~/projects/tomo2seg/condaenv/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# # History

# %%
fig, axs = plt.subplots(nrows := 2, ncols := 1, figsize=(2.5 * (sz := 5), nrows * sz), dpi=100)
fig.set_tight_layout(True)

hist_display = viz.TrainingHistoryDisplay(
    history_cb.history, 
    model_name=tomo2seg_model.name,
    loss_name=model.loss.__name__,
    x_axis_mode=(
        "epoch", "batch", "crop", "voxel", "time",
    ),
).plot(
    axs, 
    with_lr=True,
    metrics=(
        "loss", 
    ),
)

axs[0].set_yscale("log")
axs[-1].set_yscale("log")

viz.mark_min_values(hist_display.axs_metrics_[0], hist_display.plots_["loss"][0])
viz.mark_min_values(hist_display.axs_metrics_[0], hist_display.plots_["val_loss"][0], txt_kwargs=dict(rotation=0))

hist_display.fig_.savefig(
    tomo2seg_model.model_path / (hist_display.title + ".png"),
    format='png',
)
# plt.close()
# Out:
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::16:19:50.517]
# train: argmin=103 --> min=0.0139
#
# INFO::tomo2seg::{viz.py:mark_min_values:392}::[2020-12-10::16:19:50.519]
# val: argmin=101 --> min=0.0171

# %%
history_cb.dataframe.to_csv(history_cb.csv_path, index=True)

# %%
model.save(tomo2seg_model.model_path)
# Out:
# INFO:tensorflow:Assets written to: /home/users/jcasagrande/projects/tomo2seg/data/models/unet2d/unet2d.crop112-f16.fold000.1607-533-765/assets

# %%
this_nb_name = "train-04-krilin92.ipynb"
import os
this_dir = os.getcwd()
logger.warning(f"{this_nb_name=} {this_dir=}")

os.system(f"jupyter nbconvert {this_dir}/{this_nb_name} --output-dir {str(tomo2seg_model.model_path)} --to html")
# Out:
# WARNING::tomo2seg::{<ipython-input-38-b020e808e473>:<module>:004}::[2020-12-10::16:20:06.447]
# this_nb_name='train-04-krilin92.ipynb' this_dir='/home/users/jcasagrande/projects/tomo2seg/nbs'
# 0
