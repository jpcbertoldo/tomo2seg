# %%
# %load_ext autoreload
# %autoreload 2
from tomo2seg import display
import numpy as np
from matplotlib import pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
mock_slice = np.repeat(np.arange(128).reshape(-1, 1), 128, 1)
mock_slice = mock_slice + mock_slice.copy().T
mock_slice
# Out:
# array([[  0,   1,   2, ..., 125, 126, 127],
#        [  1,   2,   3, ..., 126, 127, 128],
#        [  2,   3,   4, ..., 127, 128, 129],
#        ...,
#        [125, 126, 127, ..., 250, 251, 252],
#        [126, 127, 128, ..., 251, 252, 253],
#        [127, 128, 129, ..., 252, 253, 254]])

# %%
fig, ax = plt.subplots(1, 1, figsize=(sz := 10, sz))
slice_display = display.SliceDisplay("mock", "z", 33, mock_slice).plot(ax, 0, 255)

# %%
fig, ax = plt.subplots(1, 1, figsize=(sz := 10, sz))
slice_display = display.SliceDisplay("mock", "z", 33, mock_slice).plot(ax, 0, 128)

# %%
fig, ax = plt.subplots(1, 1, figsize=(sz := 10, sz))
slice_display = display.SliceDisplay("mock", "z", 33, mock_slice).plot(ax, 0, 255, imshow_kwargs=dict(cmap="inferno"))

# %%
slice_display.fig_

# %%
slice_display.axs_
# Out:
# {'imshow': <AxesSubplot:title={'center':'mock.slicedisplay.axis=z.coord=33 vmin=0.0, vmax=255.0'}>}

# %%
slice_display.plots_
# Out:
# {'imshow': <matplotlib.image.AxesImage at 0x7f10d354a940>}
